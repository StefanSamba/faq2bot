# %%
# Open Projects
import json
with open('uploadwithexamples.json') as json_file:
    projecta = json.load(json_file)
with open('general nl.json') as json_file:
    projectb = json.load(json_file)

# %%
projectb['brains'][0].keys()
# skip brain merging
# copy flows no brainId here
# skip entity merging
# copy intents and replace brainId per intent
# copy intents and replace brainId per intent
# Out:
# dict_keys(['brain', 'flows', 'entities', 'intents', 'actions'])

# %%
def merge_flows (projecta, projectb):
    flowsa = projecta['brains'][0]['flows']
    flowsb = projectb['brains'][0]['flows']
    print("number of flows before merge = ",len(flowsa))
    for flow in flowsb:
        flowsa.append(flow)
    print("number of flows after merge = ",len(flowsa))
    return projecta
#merge_flows (projecta, projectb)

# %%
def merge_intents (projecta, projectb):
    intentsa = projecta['brains'][0]['intents']
    intentsb = projectb['brains'][0]['intents']
    brainIda = projecta['brains'][0]['brain']['brainId']
    print("number of intents before merge = ",len(intentsa))
    for intent in intentsb:
        intent['brainId']=brainIda
        intentsa.append(intent)
    for intent in intentsa:
        intent['brainId']=brainIda
        
    print("number of intents after merge = ",len(intentsa))

    return projecta
#merge_intents (projecta, projectb)

# %%
def merge_actions (projecta, projectb):
    actionsa = projecta['brains'][0]['actions']
    actionsb = projectb['brains'][0]['actions']

    brainIda = projecta['brains'][0]['brain']['brainId']
    print("number of actions before merge = ",len(actionsa))
    #print("number of actions in b = ",len(actionsb))

    for action in actionsb:
        action['brainId']=brainIda
        actionsa.append(action)
    
    for action in actionsa:
        action['brainId']=brainIda
    print("number of actions after merge = ",len(actionsa))

    return projecta
#merge_actions (projecta, projectb)

# %%
prjct = merge_flows (projecta, projectb)
prjct = merge_intents (projecta, projectb)
prjct = merge_actions (projecta, projectb)
# Out:
# number of flows before merge =  10
# number of flows after merge =  21
# number of intents before merge =  10
# number of intents after merge =  20
# number of actions before merge =  10
# number of actions after merge =  53

# %%
prjct['brains'][0]['actions']
# Out:
# [{'actionId': 'ri3no6u2q3w73ocd',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Zodra je zending ons magazijn verlaat ontvang je een barcode waarmee je de zending kunt volgen. '],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'n53ue0hk0pnw1l3j',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Het verwerken van je retourzending kan maximaal 14 dagen in beslag nemen. Wil je controleren of het is aangekomen? Dan kan dat bij onze vervoerder PostNL met de retourbarcode in combinatie met de postcode van ons magazijn (5140VB).'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'vmt2k00fgaznrz5t',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Bij je bestelling heb je een retourformulier en een antwoordetiket ontvangen. Voeg het retourformulier bij je bestelling en plak het antwoordetiket op de verzenddoos. Je kunt de zending aanbieden bij een servicepunt van PostNL waarna deze kosteloos wordt verzonden.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'slvuwo3lkmq2pteo',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Je kunt je bestelling in de winkel terugbrengen. Heb je vooraf betaald\xa0met iDEAL, Creditcard, vanHaren giftcard of PayPal? Dan ontvang je in de winkel het aankoopbedrag in contanten terug, of wordt het binnen 48 uur op je rekening bijgeschreven. Heb je gekozen voor achteraf betalen met Klarna? Dan passen wij de factuur aan - dit kan 14 dagen duren.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'jtuob5rrzfa0jkyv',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Je kunt de winkelvoorraad per artikel en maat inzien op onze online shop bij "zoek winkel". Ben je van plan onze winkel te bezoeken, dan adviseren wij je om de actuele voorraad altijd met\xa0mijn collega\'s telefonisch te bespreken.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'fz4rsg0qfj94p06i',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Na ontvangst van jouw retourzending, wordt de Klarna\xa0factuur\xa0binnen 14 werkdagen gecorrigeerd. Je ontvangt de aangepaste factuur per mail. Heb je al betaald, dan wordt het aankoopbedrag teruggestort door Klarna.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'sa9bhzou1fr6ury6',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Wanneer je op werkdagen voor 21.00uur een bestelling plaatst, wordt jouw bestelling de volgende dag geleverd. Feestdagen uitgezonderd.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '7cjawt7yarq01sjf',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Bij vanHaren\xa0bieden wij gratis verzending en retour bij een minimale bestelwaarde van €9,-. Het is niet mogelijk om een bestelling te plaatsen voor een lagere bestelwaarde.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'mb7u1xk6nsuwt1eq',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Ruilen is uitsluitend mogelijk in onze winkels binnen 30 dagen. Heb je gekozen voor achteraf betalen met Klarna, dan is het helaas niet mogelijk om een ruiling te maken. Je kunt dan een nieuwe bestelling plaatsen of het gewenste artikel in de winkel aanschaffen.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'a1xj64pxkkmvm31k',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ["Heb je deze aankoop in de winkel gedaan, dan adviseren wij je om met het artikel en het aankoopbewijs (of de pintransactie) langs te gaan bij een van onze winkels. Onze collega's kijken dan graag mee naar een passende oplossing. Heb je het artikel thuis ontvangen, dan ben je natuurlijk ook vanHarte welkom in onze winkel, maar je kunt ook contact opnemen met onze klantenservice."],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '1b416084-44b2-4bd8-8556-a36f1bb07a8f',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'integrationId': 'c97b08aa-d895-4479-b1c6-cd4104664027',
#    'integrationName': 'function',
#    'integrationTitle': 'Takeover',
#    'tags': []},
#   'type': 'ACTION'},
#  {'actionId': 'd8f09d73-ee0c-4de4-b352-fe2bf28c0b0c',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'integrationId': 'c97b08aa-d895-4479-b1c6-cd4104664027',
#    'integrationName': 'function',
#    'integrationTitle': 'Takeover',
#    'tags': []},
#   'type': 'ACTION'},
#  {'actionId': 'd6fdefa9-24c8-4f53-af75-a2a5e89c3af8',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'integrationId': 'c97b08aa-d895-4479-b1c6-cd4104664027',
#    'integrationName': 'function',
#    'integrationTitle': 'Takeover',
#    'tags': []},
#   'type': 'ACTION'},
#  {'actionId': '8deaec42-aa91-41f8-9bde-440391593bd9',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'integrationId': '029640df-df68-4647-a734-4f9aa9890899',
#    'integrationName': 'function',
#    'integrationTitle': 'Untitled Code'},
#   'type': 'ACTION'},
#  {'actionId': 'fa67d2e1-6b4e-42e1-9107-548a47282970',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'fallback': '',
#    'response': {'type': 'carousel',
#     'payload': {'cards': [{'title': 'Swipe en select below <👇>',
#        'subtitle': 'Topic 1',
#        'buttons': [{'label': 'button 1a',
#          'type': 'postback',
#          'value': ' text button 1a'},
#         {'label': 'button 1b', 'type': 'postback', 'value': ' text button 1b'},
#         {'label': 'button 1c',
#          'type': 'postback',
#          'value': ' text button 1b'}],
#        'media': {'type': 'image',
#         'url': 'https://images.unsplash.com/photo-1552664730-d307ca884978?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1350&q=80'}},
#       {'title': 'Swipe en select below <👇>',
#        'subtitle': 'Topic 2',
#        'buttons': [{'label': 'button 2a',
#          'type': 'postback',
#          'value': 'text button 2b'},
#         {'label': 'button 2b', 'type': 'postback', 'value': ' text button 2b'},
#         {'label': 'button 2c',
#          'type': 'postback',
#          'value': ' text button 2c'}],
#        'media': {'type': 'image',
#         'url': 'https://images.unsplash.com/photo-1493238792000-8113da705763?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1350&q=80'}},
#       {'title': 'Swipe en select below <👇>',
#        'buttons': [{'label': 'button 3a',
#          'type': 'postback',
#          'value': 'text button 3a'},
#         {'label': 'button 3b', 'type': 'postback', 'value': ' text button 3b'},
#         {'label': 'button 3c', 'type': 'postback', 'value': 'text button 3c'}],
#        'subtitle': 'Topic 3',
#        'media': {'type': 'image',
#         'url': 'https://images.unsplash.com/photo-1483728642387-6c3bdd6c93e5?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1355&q=80'}}]}},
#    'tags': []},
#   'type': 'CAROUSEL'},
#  {'actionId': '88bfec4f-8dbd-4e9f-9e65-609248b7342c',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'setBotToPause': True, 'secondsToPause': ''},
#   'type': 'HANDOVER'},
#  {'actionId': '9f7b1ebf-42b7-48e1-9f30-254174db9956',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'setBotToPause': True, 'secondsToPause': ''},
#   'type': 'HANDOVER'},
#  {'actionId': '5699c1b9-5daa-43d4-8526-2032f1666325',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'behaviour': 'RESET_ALL', 'params': [], 'tags': []},
#   'type': 'RESET'},
#  {'actionId': '2d1f6b97-3a3f-4640-ad9b-d2345cdd671d',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'behaviour': 'RESET_SPECIFIC_PARAMS',
#    'params': ['bericht'],
#    'tags': []},
#   'type': 'RESET'},
#  {'actionId': '96c1befb-5b44-4bf6-9c5b-f9e92988a175',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'behaviour': 'RESET_SPECIFIC_PARAMS',
#    'params': ['email'],
#    'tags': []},
#   'type': 'RESET'},
#  {'actionId': '9d09e873-e7ec-4b36-9d45-c0a21a3ceb69',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'behaviour': 'RESET_SPECIFIC_PARAMS',
#    'params': ['naam'],
#    'tags': []},
#   'type': 'RESET'},
#  {'actionId': 'aa7e2b5a-846f-49b9-8089-0e287497e290',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'fallback': '',
#    'tagActions': [{'action': 'add',
#      'tagName': 'Feedback - Negatief',
#      'tagValue': 'Feedback - Negatief'}]},
#   'type': 'TAGS'},
#  {'actionId': '8ded7157-1755-46d5-8894-7567ffd7da2b',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'fallback': '',
#    'tagActions': [{'action': 'add',
#      'tagName': 'Feedback - Positief',
#      'tagValue': 'Feedback - Positief'}]},
#   'type': 'TAGS'},
#  {'actionId': '3d721dcc-0978-4604-824b-d6c904fc94a2',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Welkom bij Organization! Ik ben Chatbot Name, jouw virtuele assistent. '],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '43f36c26-3e9d-412d-8eca-1eb8507a85d0',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Stel je vraag direct of selecteer het topic van jouw vraag zodat ik je verder kan helpen. ^Chatbot Name 🤖'],
#    'quickReplies': [],
#    'delay': 2000,
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'e2b53afe-0438-404a-992e-6ca0e4e9d12a',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Een medewerker is onderwerg om je te helpen. ^Pablo 🤖'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '13cb339b-777c-4f7a-aaa0-ba0f7e6e7632',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Momenteel is er geen live chat medewerker beschikbaar. Wil je een bericht achter laten of de menuopties zien?'],
#    'quickReplies': [{'label': 'Laat bericht achter',
#      'value': 'Start Werkpakket',
#      'type': 'event'},
#     {'label': 'Menu', 'value': 'Menu', 'type': 'event'}],
#    'tags': [],
#    'delay': 0,
#    'scope': {'channels': []}},
#   'type': 'TEXT'},
#  {'actionId': '2602f695-7aa2-4c48-9306-e25c6b45e277',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Ben je hiermee geholpen?'],
#    'quickReplies': [{'label': '👍', 'value': 'Ja', 'type': 'text'},
#     {'label': '👎', 'value': 'Nee', 'type': 'text'}],
#    'delay': 0,
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '40e4ef1f-32b7-446f-80f7-6710bd4503cf',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Super, mocht je meer vragen hebben, stel ze gerust. ^ Chatbot Name 🤖'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '87e417ab-d64a-4d1c-9d6c-182f5c17917d',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Wat jammer, laten we gelijk een bericht achter laten voor de klantenservice ^ Chatbot Name🤖'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '42144e92-f8f6-4097-acb2-4e524ceb2e6e',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Oei, ik snap je vraag niet helemaal. Je kunt jouw vraag anders stellen of ik kan je helpen om een bericht voor de klantenservice achter te laten'],
#    'quickReplies': [{'label': 'Laat bericht achter',
#      'value': 'Start Werkpakket',
#      'type': 'event'}],
#    'tags': [],
#    'delay': 0,
#    'scope': {'channels': []}},
#   'type': 'TEXT'},
#  {'actionId': '1fca320d-01d9-47e9-945a-3721278c8d55',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Ik snap het nog steeds niet. Laten we een bericht voor de klantenservice achterlaten.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'f7f89c91-c79e-4526-aa4e-0bbaef212342',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Wat is je naam?'],
#    'quickReplies': [{'label': 'Menu', 'value': 'Menu', 'type': 'event'}],
#    'delay': 0,
#    'tags': [],
#    'scope': {'channels': []}},
#   'type': 'TEXT'},
#  {'actionId': '546d5ce8-8e8e-49f6-a3bd-9fc9fb8a6146',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Op welk e-mail adres kunnen we je bereiken?'],
#    'quickReplies': [{'label': 'Menu', 'value': 'Menu', 'type': 'event'}],
#    'delay': 0,
#    'tags': [],
#    'scope': {'channels': []}},
#   'type': 'TEXT'},
#  {'actionId': 'db76b3b2-8362-439f-b1ba-853aae40c04c',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Ok, en welk bericht wil je achter laten voor de klantenservice'],
#    'quickReplies': [{'label': 'Menu', 'value': 'Menu', 'type': 'event'}],
#    'delay': 0,
#    'tags': [],
#    'scope': {'channels': []}},
#   'type': 'TEXT'},
#  {'actionId': 'fd0b12c7-5173-4e29-be2e-87395b54474e',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Hoi ik ben een template van Flow.ai om je te laten zien hoe je een werkpakket kunt maken.'],
#    'quickReplies': [{'label': 'Start Werkpakket',
#      'value': 'Start Werkpakket',
#      'type': 'event'}],
#    'delay': 0,
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '2dfe133d-943d-4e71-bd6d-6dd2631d7c56',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Ok, kloppen deze gegevens: {{naam}}, {{email}} en {{bericht}}'],
#    'quickReplies': [{'label': 'Ja', 'value': 'Ja', 'type': 'text'},
#     {'label': 'Nee', 'value': 'Nee', 'type': 'text'}],
#    'delay': 0,
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'c739f582-5bb8-46f3-85f2-05d615e1c12b',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'fallback': '', 'texts': [''], 'quickReplies': [], 'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '22b9287a-26e5-4b12-ad4f-7ce6802e7503',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Welk van de gegevens wil je aanpassen?'],
#    'quickReplies': [{'label': 'Naam',
#      'value': 'Aanpassen Naam',
#      'type': 'event'},
#     {'label': 'Email', 'value': 'Aanpassen Email', 'type': 'event'},
#     {'label': 'Bericht', 'value': 'Aanpassen Bericht', 'type': 'event'}],
#    'delay': 0,
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '3452d361-072e-45f5-90d9-f79e4588e6df',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Wat is je naam?'], 'quickReplies': [], 'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'b37ec851-8b13-4a8a-97af-5d0d52a86492',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Wat is je email?'], 'quickReplies': [], 'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'd31d13ab-211f-4268-bbf8-842789f48a80',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Welk bericht wil je doorsturen naar de klantenservice?'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'dc433ea3-dd52-4dd3-9dc9-5116deeedf1d',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Je bericht is verstuurd. We streven ernaar om je vraag binnen 48 uur te beantwoorden'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': 'dd682db5-8c2d-4a0a-b6f7-d44f0a11b5a7',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'texts': ['Open de Action hieronder om het e-mail adres in te vullen waar het werkpakket of ticket heen moet.'],
#    'quickReplies': [],
#    'tags': []},
#   'type': 'TEXT'},
#  {'actionId': '1f699609-493e-4c37-afe6-0c1ab041705a',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Opening', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': 'f6add8a8-b88d-4cda-bcbe-be4d468f8b02',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Menu', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': '1f876bb9-911b-4139-82a2-8468a464ac1a',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Menu', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': 'b1eb1488-a437-472c-8419-9aa36d664e69',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Start Werkpakket', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': '98c977ff-0e1c-4f82-abb5-2af55385210a',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Controleren Gegevens', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': '7fbe998e-f48b-4b10-9997-a0defe3397b8',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Controleren Gegevens', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': 'cea5ff9a-56ff-4b77-91e6-6b3e08e0f40e',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Controleren Gegevens', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': '9bee2ff3-cc4f-474a-b968-4d23865ced6a',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'eventName': 'Controleren Gegevens', 'tags': []},
#   'type': 'TRIGGER'},
#  {'actionId': 'f97a58e6-02d3-44e1-acd7-60c0e226818f',
#   'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#   'payload': {'fallback': '',
#    'quickReplies': [],
#    'tags': [],
#    'eventName': 'Start Werkpakket'},
#   'type': 'TRIGGER'}]

# %%
with open('projecta_test.json', 'w') as f:
    json.dump(prjct, f)

# %%
(prjct['brains'][0]['intents'])
print(projecta['brains'][0]['brain']['brainId'])
print(projectb['brains'][0]['brain']['brainId'])
# Out:
# e8ef9a45-baf6-40bf-a336-f3b195d06fbb
# 2233f6d1-2817-4ff2-bca4-e095918e66c8

# %%
(projecta['brains'][0]['actions'][0]['brainId'])
# Out:
# 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb'

# %%
projecta['brains'][0]['intents'][15] # waar is mijn bestelling
# Out:
# {'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb',
#  'title': 'Medewerker spreken',
#  'accuracy': 30.76,
#  'disableTraining': False,
#  'examples': [{'entities': [], 'query': 'Medewerker spreken'},
#   {'entities': [], 'query': 'ik wil een medewerker spreken'},
#   {'entities': [], 'query': 'hoe kan ik met een mens praten'},
#   {'entities': [], 'query': 'mens spreken'},
#   {'entities': [], 'query': 'live chatten met medewerken'},
#   {'entities': [], 'query': 'ik wil geen bot'},
#   {'entities': [], 'query': 'is er een agent online'}],
#  'intentId': '5477e66f-3447-4e23-b60e-094f6d259852'}

# %%
for flow in projecta['brains'][0]['flows']:
    if 'Medewerker'in flow['title']:
        print(flow)
# Out:
# {'group': '00 General', 'title': '04 Medewerker spreken', 'disabled': False, 'flowId': '9c523b56-b0c2-4d93-b917-f4363f548aba', 'metadata': [], 'steps': [{'type': 'INTENT', 'title': 'Medewerker spreken', 'contexts': [], 'actions': [{'actionId': '13cb339b-777c-4f7a-aaa0-ba0f7e6e7632'}], 'stepId': 'fe71fe9c-02f3-4a6f-b4c0-38cb452dee9a', 'intent': {'intentId': '5477e66f-3447-4e23-b60e-094f6d259852'}}], 'isChannelSpecific': False}

# %%
for action in projecta['brains'][0]['actions']:
    if action['actionId']== '13cb339b-777c-4f7a-aaa0-ba0f7e6e7632':
        print(action)
# Out:
# {'actionId': '13cb339b-777c-4f7a-aaa0-ba0f7e6e7632', 'brainId': 'e8ef9a45-baf6-40bf-a336-f3b195d06fbb', 'payload': {'texts': ['Momenteel is er geen live chat medewerker beschikbaar. Wil je een bericht achter laten of de menuopties zien?'], 'quickReplies': [{'label': 'Laat bericht achter', 'value': 'Start Werkpakket', 'type': 'event'}, {'label': 'Menu', 'value': 'Menu', 'type': 'event'}], 'tags': [], 'delay': 0, 'scope': {'channels': []}}, 'type': 'TEXT'}
