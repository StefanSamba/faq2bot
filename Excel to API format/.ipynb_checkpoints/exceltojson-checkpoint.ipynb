# %%
import pandas as pd
import json
from flask import jsonify

print("Preparing Data")
# Work with XSLX and define variables

xls = pd.ExcelFile("FAQ.xlsx")
df1 = pd.read_excel(xls, "FAQ's")
df = pd.DataFrame()
df['Questions']=list(df1['Question'])
df['Answers']=list(df1['Answer'])
df['Topic']=list(df1['Topic'])
n_items = max(df.count())
qa = df[:n_items]

# get Organization Info
df2 = pd.read_excel(xls, "Introduction")
df2.columns = ['row', 'faq2bot instruction', 'none', 'label', 'value']
orgdict = df2.set_index('label')['value'].to_dict()
questions = list(qa['Questions'])
answers = list(qa['Answers'])
topics = list(qa['Topic'])
# Out:
# Preparing Data
# Data Prepared

# %%
for key in orgdict:
    print('orgdict["{}"]'.format(key))

print("Data Prepared")
print("Starting Request")
# Out:
# orgdict["nan"]
# orgdict["Organization"]
# orgdict["Language"]
# orgdict["Chatbot Name"]
# orgdict["Support Email"]

# %%
import requests

url = "https://botcreator.ew.r.appspot.com/"

payload = json.dumps({
    "textgen": "false",
    "language": orgdict["Language"],
    "questions": [
        "questions"
    ],
    "answers": [
        "answers"
    ],
    "topics": [
        "topics"
    ],
    "chatbotName": orgdict["Chatbot Name"],
    "organizationName": orgdict["Organization"],
    "supportEmail": orgdict["Support Email"],
    "handoffType": "ticket"
})


headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data = payload)

#print(response.text.encode('utf8'))
print("Response received")
# Out:
# b'{"brains":[{"actions":[{"actionId":"9b0c96b4-0d99-4e56-b92b-b606cb764077","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"integrationId":null,"integrationName":"function","integrationTitle":"Takeover","tags":[]},"type":"ACTION"},{"actionId":"66a4e92d-b736-462a-bf34-d41e0843ee92","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"integrationId":null,"integrationName":"function","integrationTitle":"Takeover","tags":[]},"type":"ACTION"},{"actionId":"466822fb-f030-4406-b0c4-09b015c88582","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"integrationId":null,"integrationName":"function","integrationTitle":"Takeover","tags":[]},"type":"ACTION"},{"actionId":"3523f68f-7058-4de0-9d59-2d7a2c4f2ebe","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"integrationId":null,"integrationName":"function","integrationTitle":"Untitled Code"},"type":"ACTION"},{"actionId":"c1e6b2ce-51d3-4d54-af5f-e50b8dcdf060","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"fallback":"","response":{"payload":{"cards":[{"buttons":[{"label":"questions","type":"postback","value":"questions"}],"media":{"type":"image","url":"https://source.unsplash.com/featured/?topics"},"subtitle":"topics","title":"Swipe en select below <\\ud83d\\udc47>"}]},"type":"carousel"},"tags":[]},"type":"CAROUSEL"},{"actionId":"1d9f3ba8-2023-4e05-8046-edfaf5e0064f","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"secondsToPause":"","setBotToPause":true},"type":"HANDOVER"},{"actionId":"67e9fb26-cdaa-4f75-ac8d-39b067442fb9","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"secondsToPause":"","setBotToPause":true},"type":"HANDOVER"},{"actionId":"b8257317-a978-4bee-9cae-42119605000c","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"behaviour":"RESET_ALL","params":[],"tags":[]},"type":"RESET"},{"actionId":"8a30857d-b346-4ae1-9b62-39ecdc1dca5a","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"behaviour":"RESET_SPECIFIC_PARAMS","params":["bericht"],"tags":[]},"type":"RESET"},{"actionId":"fa69ea2d-edc8-4bed-9482-502541ed3383","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"behaviour":"RESET_SPECIFIC_PARAMS","params":["email"],"tags":[]},"type":"RESET"},{"actionId":"32392f8d-b55e-4865-a12a-e5f9ce984b68","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"behaviour":"RESET_SPECIFIC_PARAMS","params":["naam"],"tags":[]},"type":"RESET"},{"actionId":"720ed07b-d030-44b2-8032-5e9ffc8dd8ef","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"fallback":"","tagActions":[{"action":"add","tagName":"Feedback - Negatief","tagValue":"Feedback - Negatief"}]},"type":"TAGS"},{"actionId":"b0b581a2-610d-4034-951e-3c8b8ad450e9","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"fallback":"","tagActions":[{"action":"add","tagName":"Feedback - Positief","tagValue":"Feedback - Positief"}]},"type":"TAGS"},{"actionId":"4f6b10b4-37ac-49e5-92b1-94b6fcd4dd52","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"quickReplies":[],"tags":[],"texts":["Welkom bij Print Mijn Stad! Ik ben Pablo, jouw virtuele assistent."]},"type":"TEXT"},{"actionId":"00031788-688b-4b88-9b5f-c53a532a48ff","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"delay":2000,"quickReplies":[],"tags":[],"texts":["Stel je vraag direct of selecteer het topic van jouw vraag zodat ik je verder kan helpen.  \\ud83e\\udd16"]},"type":"TEXT"},{"actionId":"bae76d87-a6f2-41f6-9ef6-3b3acd0722f3","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"quickReplies":[],"tags":[],"texts":["Een medewerker is onderwerg om je te helpen. ^Pablo \\ud83e\\udd16"]},"type":"TEXT"},{"actionId":"219c0b2a-02f2-4bdc-913e-f5851a34086f","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"delay":0,"quickReplies":[],"scope":{"channels":[]},"tags":[],"texts":["Liever een medewerker spreken?"]},"type":"TEXT"},{"actionId":"ff8d276d-226f-486a-8f3e-bc9dd19a3a23","brainId":"6e7bb309-d2b2-48ba-b5b3-6f065ee18f81","payload":{"del ...

# %%
with open("upload_"+str(orgdict["Organization"])+",json", mode='wb') as localfile:     
    localfile.write(response.content)

print("Saved to file")
